# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
# Your code here:
data = pd.read_csv("Current_Employee_Names__Salaries__and_Position_Titles.csv")

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:

data.head(60)
# Out:
#                         name                                     job_titles  \
# 0     ADRIANO,  RACQUEL ANNE                                      PARAMEDIC
# 1          AFFANEH,  MAHIR A                                 POLICE OFFICER
# 2          AFOENYI,  PHYLLIS                      TITLE V PROGRAM TRAINEE I
# 3            AGAR,  BULENT B                            DEPUTY COMMISSIONER
# 4            AGEE,  LAWRENCE                                 POLICE OFFICER
# 5          AGNEW,  ANTONIO E                             MOTOR TRUCK DRIVER
# 6          AGNEW,  MELISSA M                                       SERGEANT
# 7          AGOSTA,  JOSEPH J         POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 8    AGOSTINELLI,  MICHAEL A        FIREFIGHTER (PER ARBITRATORS AWARD)-EMT
# 9          AGOSTINI,  LUIS R                                       ASST DIR
# 10         AGOSTO,  HECTOR I          POLICE OFFICER/EXPLSV DETECT K9 HNDLR
# ...

# %%
data.columns = data.columns.str.lower().str.replace(' ', '_')

# %%
data
# Out:
#                          name                 job_titles        department  \
# 0      ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1           AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2           AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3             AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4             AGEE,  LAWRENCE             POLICE OFFICER            POLICE
# ...                       ...                        ...               ...
# 33697      ZYLINSKA,  KLAUDIA             POLICE OFFICER            POLICE
# 33698      ZYMANTAS,  LAURA C             POLICE OFFICER            POLICE
# 33699       ZYMANTAS,  MARK E             POLICE OFFICER            POLICE
# 33700     ZYRKOWSKI,  CARLO E             POLICE OFFICER            POLICE
# 33701     ZYSKOWSKI,  DARIUSZ    CHIEF DATA BASE ANALYST              DAIS
#
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:

data.isna().sum()
# Out:
# name                     0
# job_titles               0
# department               0
# full_or_part-time        0
# salary_or_hourly         0
# typical_hours        25528
# annual_salary         8174
# hourly_rate          25528
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
data["salary_or_hourly"].unique()
# Out:
# array(['Salary', 'Hourly'], dtype=object)

# %%
# Your code here:

data["salary_or_hourly"].value_counts()
# Out:
# Salary    25528
# Hourly     8174
# Name: salary_or_hourly, dtype: int64

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:

display(data.groupby(['department'])['name'].agg("count"))
# Out:
# department
# ADMIN HEARNG              38
# ANIMAL CONTRL             75
# AVIATION                1856
# BOARD OF ELECTION        111
# BOARD OF ETHICS            8
# BUDGET & MGMT             44
# BUILDINGS                258
# BUSINESS AFFAIRS         167
# CITY CLERK                88
# CITY COUNCIL             362
# COPA                     123
# CULTURAL AFFAIRS          74
# DAIS                    1033
# DISABILITIES              28
# FAMILY & SUPPORT         656
# FINANCE                  544
# FIRE                    4627
# HEALTH                   467
# HOUSING                   66
# HOUSING & ECON DEV       154
# HUMAN RELATIONS           17
# HUMAN RESOURCES           75
# INSPECTOR GEN             95
# LAW                      398
# LICENSE APPL COMM          1
# MAYOR'S OFFICE           104
# OEMC                    1737
# POLICE                 13848
# POLICE BOARD               2
# PROCUREMENT               84
# PUBLIC LIBRARY          1088
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
display(len(data["name"]))
len(data)
# Out:
# 33702
# 33702

# %%
data.dtypes
# Out:
# name                  object
# job_titles            object
# department            object
# full_or_part-time     object
# salary_or_hourly      object
# typical_hours        float64
# annual_salary        float64
# hourly_rate          float64
# dtype: object

# %%
data["hourly_rate"].value_counts(dropna=False)
# Out:
# NaN      25528
# 37.45     1495
# 43.72      779
# 38.52      528
# 19.86      345
#          ...
# 33.00        1
# 52.43        1
# 26.90        1
# 21.84        1
# 37.69        1
# Name: hourly_rate, Length: 179, dtype: int64

# %%
# Degrees of freedom
degrees_freedom = 33702 - 1 #(n-1)

# %% [markdown]
# # sample mean

# %%
import numpy as np
sample_mean =data["hourly_rate"].mean()
sample_mean
# Out:
# 34.58644971862046

# %%
# Out:
# 34.58644971862046

# %%
# Your cod
import scipy.stats
confidence_level = 0.95

#sample_mean = np.mean(data)

sample_standard_error = scipy.stats.sem(data["hourly_rate"].dropna())

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

# %%
#
confidence_interval
# Out:
# (34.298427706540195, 34.87447173070072)

# %% [markdown]
# # OUR Hypothsesis

# %%
#Ho meaan H/p =  $30/hr.
#H1 mean H/p !=  $30/hr.

# %%
from scipy.stats import ttest_1samp

stat, pval = ttest_1samp((data["hourly_rate"].dropna()), 30)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)
# Out:
# stat is   31.211500329216044
# pvalue for the two-tailed test is  3.825475847673794e-202

# %% [markdown]
# # Decision

# %% [markdown]
# ## p value (3.825475847673794e-202) <  (0.05) Level of significance; hence we reject Ho.

# %% [markdown]
# ## Since we  reject the null hypothesis, it implies our the mean hourly wage is not significantly different from  $30/hr.

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
data["annual_salary"].value_counts(dropna=False)
# Out:
# NaN         8174
# 90024.0     1743
# 84054.0     1500
# 93354.0     1469
# 72510.0     1307
#             ...
# 113304.0       1
# 107112.0       1
# 80088.0        1
# 69720.0        1
# 65976.0        1
# Name: annual_salary, Length: 925, dtype: int64

# %%
police_salary = data.loc[data['department'] == 'POLICE']
police_salary.head(5)
len(police_salary)
# Out:
# 13848

# %%
import scipy.stats

confidence_level = 0.95
degrees_freedom = len(police_salary) - 1  # (n-1) or, for large values of sample size, just use that

# %% [markdown]
# # Sample mean

# %%
sample_mean = police_salary["annual_salary"].mean()
sample_mean
# Out:
# 88834.11892361111

# %% [markdown]
# # Sample standard Error

# %%
sample_standard_error = scipy.stats.sem(data["annual_salary"].dropna())
sample_standard_error
# Out:
# 132.2613823282275

# %% [markdown]
# # confidence interval

# %%
confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)
confidence_interval
# Out:
# (88574.86871670473, 89093.36913051749)

# %% [markdown]
# # Null and Alternative Hypothesis

# %%
# Your code here:

#Ho meaan H/p >=  $86000/year .
#H1 mean H/p  < $86000/year 

from scipy.stats import ttest_1samp

stat, pval = ttest_1samp((data["annual_salary"].dropna()), 86000)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval/2)
# Out:
# stat is   23.149576589194083
# pvalue for the two-tailed test is  1.1882570425863358e-117

# %% [markdown]
# # Decision

# %% [markdown]
# ## p value (1.1882570425863358e-117) <  (0.05) Level of significance; hence we reject Ho.

# %% [markdown]
# # Since we reject Ho, it implies the mean annual salary for the police is  higher than last year's mean of $86000/year  for all salaried employees

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %% [markdown]
# # STREETS & SAN has the most hourly rate

# %%
# Your code here:
# ste the crosstab MARGIN to True. this sums up the numerical column
data_crosstab = pd.crosstab(data['department'], data['hourly_rate'], margins= True)
data_crosstab
# Out:
# hourly_rate          2.65  8.25  9.74  10.0  10.5  12.0  13.0  13.4  13.45  \
# department
# ANIMAL CONTRL           0     0     0     0     0     0     0     0      0
# AVIATION                0     0     0     0     0     0     0     0      0
# BUDGET & MGMT           0     0     0     0     0     0     2     0      0
# BUSINESS AFFAIRS        0     0     0     0     0     0     2     0      0
# CITY COUNCIL            0     4     0     2     1     5     5     0      1
# CULTURAL AFFAIRS        0     0     0     0     0     0     0     0      0
# DAIS                    0     0     0     0     0     0     0     0      0
# DISABILITIES            0     0     0     0     0     0     1     0      0
# FAMILY & SUPPORT      260     0     0     0     0     0    41     0      0
# FINANCE                 0     0     0     0     0     0     0     0      0
# HEALTH                  0     0     0     0     0     0     0     0      0
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
data_street_san = data.loc[data['department'] == 'STREETS & SAN']


len(data_street_san)
# Out:
# 2175

# %%
import scipy.stats

confidence_level = 0.95
degrees_freedom = len(data_street_san) - 1

# %% [markdown]
# # Sample Mean

# %%
sample_mean = data_street_san["hourly_rate"].mean()
sample_mean
# Out:
# 35.55229685807062

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %% [markdown]
# # Same confidence interval was used for the first hypothesis testing

# %%
# Your code here:
import scipy.stats
confidence_level = 0.95

#sample_mean = np.mean(data)

sample_standard_error = scipy.stats.sem(data["hourly_rate"].dropna())

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)
confidence_interval
# Out:
# (35.26412475324628, 35.84046896289496)

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
print(len(data["name"]))
degrees_freedom = len(data["name"]) -1
degrees_freedom
# Out:
# 33702
# 33701

# %%
sample_standard_error = scipy.stats.sem(data["hourly_rate"].dropna())

# %% [markdown]
# # Again, I stopped Because I used the same confidence Interval to test the $86000/year salary  for all salaried employees in the previous question

# %%
# Your code here:

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
